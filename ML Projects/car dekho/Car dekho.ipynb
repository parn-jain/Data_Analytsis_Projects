# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import datasets
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import linear_model

# %%
data = pd.read_csv(r'CAR DETAILS FROM CAR DEKHO.csv')
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
data.drop_duplicates(inplace = True)

# %%
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
# fuelAn = data.groupby('fuel').mean().reset_index()
sns.stripplot(x = 'fuel',y = 'selling_price', data = data,hue = 'owner')
# Out:
# <AxesSubplot: xlabel='fuel', ylabel='selling_price'>

# %%
binsl = [0,10000,20000,30000,40000,50000,60000,70000,80000,90000,100000,110000,120000,130000,140000,150000]
sns.scatterplot(x = data['km_driven'], y = data['selling_price'],data = data)
# Out:
# <AxesSubplot: xlabel='km_driven', ylabel='selling_price'>

# %%
sns.stripplot(x = 'transmission',y = 'selling_price', data = data)
# Out:
# <AxesSubplot: xlabel='transmission', ylabel='selling_price'>

# %%
sns.countplot(x = 'owner', data = data)
# Out:
# <AxesSubplot: xlabel='owner', ylabel='count'>

# %%
sns.boxplot(y = 'selling_price',data = data)
Ndata = data.copy()

# %%
Ndata = Ndata[Ndata['selling_price']<8000000]
sns.boxplot(y = 'selling_price',data = Ndata)
# Out:
# <AxesSubplot: ylabel='selling_price'>

# %%
Ndata = Ndata[Ndata['selling_price']<5000000]
sns.boxplot(y = 'selling_price',data = Ndata)
# Out:
# <AxesSubplot: ylabel='selling_price'>

# %%
Ndata = Ndata[Ndata['selling_price']<4000000]
sns.boxplot(y = 'selling_price',data = Ndata)
# Out:
# <AxesSubplot: ylabel='selling_price'>

# %%
# Ndata = Ndata[Ndata['selling_price']<3500000]
# sns.boxplot(y = 'selling_price',data = Ndata)

# %%
# Ndata = Ndata[Ndata['selling_price']<3000000]
# sns.boxplot(y = 'selling_price',data = Ndata)

# %%
# Ndata = Ndata[Ndata['selling_price']<2500000]
# sns.boxplot(y = 'selling_price',data = Ndata)

# %%
# Ndata = Ndata[Ndata['selling_price']<2000000]
# sns.boxplot(y = 'selling_price',data = Ndata)

# %%
# Ndata = Ndata[Ndata['selling_price']<2500000]
# sns.boxplot(y = 'selling_price',data = Ndata)

# %%
# reg = linear_model.LinearRegression()
# reg.fit(x_train,y_train)

# %%
sns.boxplot(y = 'selling_price',data = data)
# Out:
# <AxesSubplot: ylabel='selling_price'>

# %%
mean1 = data['selling_price'].mean()
std1 = data['selling_price'].std()
lower_bound = mean1 - std1*2
upper_bound = mean1 + std1*2
 
# Drop the outliers
Exp1 = data[(data['selling_price'] >= lower_bound)
                & (data['selling_price'] <= upper_bound)]
Exp1.shape[0]
# Out:
# 3469

# %%
mean2 = Ndata['selling_price'].mean()
std2 = Ndata['selling_price'].std()
lower_bound = mean2 - std2*2
upper_bound = mean2 + std2*2
# Drop the outliers
Exp2 = Ndata[(Ndata['selling_price'] >= lower_bound)
                & (Ndata['selling_price'] <= upper_bound)]
Exp2.shape[0]
Ndata.shape[0]
# Out:
# 3563

# %%
sns.displot(x = 'selling_price', data = data)

# %%
finaldata = data[data['selling_price']<3500000]
finaldata
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
sns.boxplot(y ='km_driven',data = finaldata)
finaldata = finaldata[finaldata['km_driven']<2000000]

# %%
le = LabelEncoder()
finaldata['fuel'] = le.fit_transform(finaldata['fuel'])
finaldata['seller_type'] = le.fit_transform(finaldata['seller_type'])
finaldata['transmission'] = le.fit_transform(finaldata['transmission'])
finaldata['owner'] = le.fit_transform(finaldata['owner'])

# %%
# MLdata = data.copy()
finaldata.drop(columns=['name'],inplace = True)
X = finaldata.drop(columns=['selling_price'])
Y = finaldata[['selling_price']]
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 1)

# %%
reg = linear_model.LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regp = reg.predict(x_test)
regp2 = np.array(regp).reshape(-1)

# %%
plt.plot(x_test,regp2,color = 'red')

# %%
plt.plot(x_test,y_test,color = 'red')

# %%
new = pd.concat([x_test.km_driven.reset_index(drop = True),pd.Series(regp2)],axis = 1)
new.sort_values(by = 'km_driven',inplace = True)
new
# Out:
#      km_driven              0
# 441          1  585453.619108
# 746        101  581303.667533
# 595        101  815185.789416
# 110       1000  573196.644990
# 703       1000  573196.644990
# ..         ...            ...
# 964     250000  108418.809009
# 757     260000  409543.435381
# 494     280000  310422.453467
# 178     300000   -5282.851932
# 297     347089  229671.192369
#
# [1068 rows x 2 columns]

# %%
plt.plot(new['km_driven'],new[0])

# %%
from sklearn.metrics import mean_squared_error
import numpy as np



rmse = np.sqrt(mean_squared_error(y_test, regp))
print("RMSE:", rmse)
# Out:
# RMSE: 274063.3211921816
