# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'SuperStore_Sales_Dataset.csv')
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
# ...                ...             ...         ...         ...
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
# 5897              1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898              5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 1     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 2     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 3        First Class    LR-16915       Lena Radford   Consumer  United States
# 4     Standard Class    CA-12310  Christine Abelman  Corporate  United States
# ...              ...         ...                ...        ...            ...
# 5896  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5897  Standard Class    EB-13975         Erica Bern  Corporate  United States
# 5898  Standard Class    JM-15580      Jill Matthias   Consumer  United States
# 5899  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias   Consumer  United States
#
#                City       State   Region       Product ID         Category  \
# 0      Gaithersburg    Maryland     East  FUR-BO-10004709        Furniture
# 1      Gaithersburg    Maryland     East  FUR-BO-10004709        Furniture
# 2      Gaithersburg    Maryland     East  TEC-PH-10000455       Technology
# 3       Los Angeles  California     West  OFF-ST-10003692  Office Supplies
# 4       San Antonio       Texas  Central  TEC-AC-10002217       Technology
# ...             ...         ...      ...              ...              ...
# 5896  New York City    New York     East  FUR-BO-10003441        Furniture
# 5897      Fairfield  California     West  OFF-BI-10002103  Office Supplies
# 5898       Loveland    Colorado     West  OFF-FA-10003472  Office Supplies
# 5899  New York City    New York     East  OFF-BI-10003684  Office Supplies
# 5900       Loveland    Colorado     West  OFF-FA-10003472  Office Supplies
#
#      Sub-Category                                       Product Name  \
# 0       Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 1       Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 2          Phones                                        GE 30522EE2
# 3         Storage  Recycled Steel Personal File for Hanging File ...
# 4     Accessories                Imation Clip USB flash drive - 8 GB
# ...           ...                                                ...
# 5896    Bookcases  Bush Westfield Collection Bookcases, Fully Ass...
# 5897      Binders    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl
# 5898    Fasteners                                Bagged Rubber Bands
# 5899      Binders               Wilson Jones Legal Size Ring Binders
# 5900    Fasteners                                Bagged Rubber Bands
#
#          Sales  Quantity   Profit  Returns Payment Mode  ind1  ind2
# 0       73.940         1  28.2668      NaN       Online   NaN   NaN
# 1      173.940         3  38.2668      NaN       Online   NaN   NaN
# 2      231.980         2  67.2742      NaN        Cards   NaN   NaN
# 3      114.460         2  28.6150      NaN       Online   NaN   NaN
# 4       30.080         2  -5.2640      NaN       Online   NaN   NaN
# ...        ...       ...      ...      ...          ...   ...   ...
# 5896   213.136         4  12.1176      NaN          COD   NaN   NaN
# 5897   295.904         2   4.5188      1.0       Online   NaN   NaN
# 5898   388.024         3  -0.6048      NaN       Online   NaN   NaN
# 5899   462.776         3  19.7910      NaN          COD   NaN   NaN
# 5900  2975.510         3  -0.6048      NaN          COD   NaN   NaN
#
# [5901 rows x 23 columns]

# %%
pd.Series(data.columns)
# Out:
# 0     Row ID+O6G3A1:R6
# 1             Order ID
# 2           Order Date
# 3            Ship Date
# 4            Ship Mode
# 5          Customer ID
# 6        Customer Name
# 7              Segment
# 8              Country
# 9                 City
# 10               State
# 11              Region
# 12          Product ID
# 13            Category
# 14        Sub-Category
# 15        Product Name
# 16               Sales
# 17            Quantity
# 18              Profit
# 19             Returns
# 20        Payment Mode
# 21                ind1
# 22                ind2
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   object
#  3   Ship Date         5901 non-null   object
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
#  8   Country           5901 non-null   object
#  9   City              5901 non-null   object
#  10  State             5901 non-null   object
#  11  Region            5901 non-null   object
#  12  Product ID        5901 non-null   object
#  13  Category          5901 non-null   object
#  14  Sub-Category      5901 non-null   object
#  15  Product Name      5901 non-null   object
#  16  Sales             5901 non-null   float64
#  17  Quantity          5901 non-null   int64
#  18  Profit            5901 non-null   float64
#  19  Returns           287 non-null    float64
#  20  Payment Mode      5901 non-null   object
#  21  ind1              0 non-null      float64
#  22  ind2              0 non-null      float64
# dtypes: float64(5), int64(2), object(16)
# memory usage: 1.0+ MB

# %%
data.drop(columns = ['ind1','ind2'], inplace = True)

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\2222965496.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Order Date'] = pd.to_datetime(data['Order Date'])
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\2222965496.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   datetime64[ns]
#  3   Ship Date         5901 non-null   datetime64[ns]
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
#  8   Country           5901 non-null   object
#  9   City              5901 non-null   object
#  10  State             5901 non-null   object
#  11  Region            5901 non-null   object
#  12  Product ID        5901 non-null   object
#  13  Category          5901 non-null   object
#  14  Sub-Category      5901 non-null   object
#  15  Product Name      5901 non-null   object
#  16  Sales             5901 non-null   float64
#  17  Quantity          5901 non-null   int64
#  18  Profit            5901 non-null   float64
#  19  Returns           287 non-null    float64
#  20  Payment Mode      5901 non-null   object
# dtypes: datetime64[ns](2), float64(3), int64(2), object(14)
# memory usage: 968.3+ KB

# %%
y2019 = data[data['Order Date'].dt.year.isin([2019])]
y2020 = data[data['Order Date'].dt.year.isin([2020])]

# %%
data.columns
# Out:
# Index(['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Profit', 'Returns', 'Payment Mode'],
#       dtype='object')

# %%
october_data2019 = y2019[y2019['Order Date'].dt.month == 10]
october_data2020 = y2020[y2020['Order Date'].dt.month == 10]

# %%
october_data2019
october_data2020
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 2776              1535  CA-2020-124086 2020-10-02 2020-02-14  Standard Class
# 2777              2368  CA-2020-123659 2020-10-02 2020-02-13     First Class
# 2903              6689  CA-2020-140494 2020-10-03 2020-03-15    Second Class
# 2904              8413  CA-2020-132290 2020-10-03 2020-03-14  Standard Class
# 2905              1256  CA-2020-144638 2020-10-03 2020-03-14  Standard Class
# ...                ...             ...        ...        ...             ...
# 5652              1509  CA-2020-108294 2020-10-12 2020-10-12        Same Day
# 5653              2773  CA-2020-158967 2020-10-12 2020-12-12     First Class
# 5654              1059  CA-2020-167150 2020-10-12 2020-12-17  Standard Class
# 5655              3246  US-2020-140907 2020-10-12 2020-12-12    Second Class
# 5656              3528  CA-2020-148922 2020-10-12 2020-12-15    Second Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 2776    MP-18175      Mike Pelletier  Home Office  United States
# 2777    MN-17935      Michael Nguyen     Consumer  United States
# 2903    CM-11815     Candace McMahon    Corporate  United States
# 2904    MD-17350       Maribeth Dona     Consumer  United States
# 2905    MH-18115      Mick Hernandez  Home Office  United States
# ...          ...                 ...          ...            ...
# 5652    LS-16975    Lindsay Shagiari  Home Office  United States
# 5653    BT-11680      Brian Thompson     Consumer  United States
# 5654    BP-11185        Ben Peterman    Corporate  United States
# 5655    BP-11185        Ben Peterman    Corporate  United States
# 5656    SU-20665  Stephanie Ulpright  Home Office  United States
#
#                  City         State   Region       Product ID  \
# 2776    Laguna Niguel    California     West  FUR-BO-10004015
# 2777          Clinton      Maryland     East  OFF-PA-10002464
# 2903    San Francisco    California     West  TEC-AC-10004568
# 2904           Dallas         Texas  Central  FUR-TA-10002228
# 2905          Chester  Pennsylvania     East  FUR-FU-10003724
# ...               ...           ...      ...              ...
# 5652            Omaha      Nebraska  Central  OFF-BI-10004965
# 5653  Fort Lauderdale       Florida    South  FUR-FU-10001940
# 5654        San Diego    California     West  OFF-BI-10001597
# 5655          Seattle    Washington     West  TEC-AC-10004510
# 5656          Jackson   Mississippi    South  OFF-BI-10003476
#
#              Category Sub-Category  \
# 2776        Furniture    Bookcases
# 2777  Office Supplies        Paper
# 2903       Technology  Accessories
# 2904        Furniture       Tables
# 2905        Furniture  Furnishings
# ...               ...          ...
# 5652  Office Supplies      Binders
# 5653        Furniture  Furnishings
# 5654  Office Supplies      Binders
# 5655       Technology  Accessories
# 5656  Office Supplies      Binders
#
#                                            Product Name     Sales  Quantity  \
# 2776   Bush Andora Bookcase, Maple/Graphite Gray Finish   226.983         2
# 2777     HP Office Recycled Paper (20Lb. and 87 Bright)  1958.120         4
# 2903                        Maxell LTO Ultrium - 800 GB   123.960         4
# 2904  Bevis Traditional Conference Table Top, Plinth...   948.408         4
# 2905               Westinghouse Clip-On Gooseneck Lamps    81.696         1
# ...                                                 ...       ...       ...
# 5652  Ibico Covers for Plastic or Wire Binding Elements   301.500         3
# 5653                         Staple-based wall hangings   396.104         3
# 5654  Wilson Jones Ledger-Size, Piano-Hinge Binder, ...   147.568         2
# 5655    Logitech Desktop MK120 Mouse and keyboard Combo   447.080         3
# 5656                        Avery Metallic Poly Binders   354.840         8
#
#         Profit  Returns Payment Mode
# 2776   16.7986      NaN          COD
# 2777   11.3288      NaN          COD
# 2903   21.2724      NaN       Online
# 2904 -173.3472      NaN       Online
# 2905    0.5022      NaN          COD
# ...        ...      ...          ...
# 5652   15.5250      1.0       Online
# 5653    5.7312      NaN        Cards
# 5654   22.9488      NaN          COD
# 5655    4.9080      NaN       Online
# 5656   22.0032      NaN          COD
#
# [272 rows x 21 columns]

# %%
oct19city = october_data2019.City.unique()
oct19city.shape
# Out:
# (67,)

# %%
year19city = y2019.City.unique()
year19city.shape
# Out:
# (320,)

# %%
year20city = y2020.City.unique()
year20city.shape
# Out:
# (350,)

# %%
oct20city = october_data2019.City.unique()
oct20city.shape
# Out:
# (67,)

# %%
city = np.intersect1d(oct20city, oct19city, assume_unique=True)
city.shape
# Out:
# (67,)

# %%
city
# Out:
# array(['Appleton', 'Arlington', 'Aurora', 'Bakersfield', 'Baltimore',
#        'Belleville', 'Boynton Beach', 'Bridgeton', 'Bristol', 'Chicago',
#        'Columbia', 'Columbus', 'Dallas', 'Denver', 'Detroit', 'Edmonds',
#        'El Cajon', 'Fort Lauderdale', 'Fresno', 'Glendale', 'Greensboro',
#        'Greenville', 'Greenwood', 'Hampton', 'Hollywood', 'Houston',
#        'Jackson', 'Jacksonville', 'La Porte', 'Lakewood', 'Lansing',
#        'Laredo', 'Lebanon', 'Long Beach', 'Longview', 'Los Angeles',
#        'Manchester', 'Mesa', 'Miami', 'New York City', 'Newark',
#        'North Las Vegas', 'Oklahoma City', 'Perth Amboy', 'Philadelphia',
#        'Richmond', 'Riverside', 'Rochester', 'Roseville', 'Sacramento',
#        'Salt Lake City', 'San Antonio', 'San Diego', 'San Francisco',
#        'San Luis Obispo', 'Seattle', 'Springfield', 'Sterling Heights',
#        'Tampa', 'Tempe', 'Toledo', 'Trenton', 'Troy', 'Tulsa',
#        'Warner Robins', 'Watertown', 'Yuma'], dtype=object)

# %%
symmetric_difference = np.setxor1d(oct20city, oct19city)

# %%
symmetric_difference
# Out:
# array([], dtype=object)

# %%
october_data2019.groupby('City').sum().reset_index().sort_values(by = 'Profit',ascending = False)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\1298464639.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   october_data2019.groupby('City').sum().reset_index().sort_values(by = 'Profit',ascending = False)
#                City  Row ID+O6G3A1:R6      Sales  Quantity     Profit  Returns
# 41  North Las Vegas             23454   4685.076        12  1691.3097      0.0
# 35      Los Angeles            141464  13278.242       102  1547.6515      0.0
# 39    New York City            170725   4206.542       109  1189.6874      0.0
# 10         Columbia             17781   2377.560        10   972.2454      0.0
# 53    San Francisco             84673   3823.368        78   678.7686      0.0
# ..              ...               ...        ...       ...        ...      ...
# 31           Laredo             10830    362.342        18  -133.2227      0.0
# 13           Denver             23907    227.658         5  -180.2625      0.0
# 29         Lakewood              6286    661.176         2  -231.4116      0.0
# 44     Philadelphia             26581   1642.422        19  -441.8017      0.0
# 2            Aurora              3729    752.410         8  -461.2000      0.0
#
# [67 rows x 6 columns]

# %%
october_data2020.groupby('City').sum().reset_index().sort_values(by = 'Profit',ascending = False)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\670090447.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   october_data2020.groupby('City').sum().reset_index().sort_values(by = 'Profit',ascending = False)
#              City  Row ID+O6G3A1:R6     Sales  Quantity     Profit  Returns
# 45  New York City             47857  7059.534        58  5514.8316      0.0
# 60     Sacramento             26574  5473.884        13  1938.3776      0.0
# 63  San Francisco             55550  4211.529        70   701.8985     10.0
# 11       Columbus             17532  2027.620        23   457.4898      0.0
# 42       Muskogee              3663  1768.030         9   437.2856      0.0
# ..            ...               ...       ...       ...        ...      ...
# 59     Round Rock              3317   353.960         5  -427.4500      0.0
# 78           Yuma              7282   645.985         5  -479.9880      0.0
# 10       Columbia             18875  2199.446        16  -946.0295      0.0
# 8         Chicago             45378  2139.633        28 -1294.2027      0.0
# 5      Burlington              2929  1677.188         4 -1306.5504      0.0
#
# [79 rows x 6 columns]

# %%
oct19states = october_data2019.State.unique()
oct19states.shape
oct19states
# Out:
# array(['Washington', 'New York', 'Pennsylvania', 'California', 'Arizona',
#        'Ohio', 'Illinois', 'Texas', 'Tennessee', 'Florida',
#        'North Carolina', 'Colorado', 'Wisconsin', 'Utah', 'Oklahoma',
#        'Virginia', 'Missouri', 'New Jersey', 'Michigan', 'Connecticut',
#        'Delaware', 'Maryland', 'Nevada', 'Georgia', 'Indiana'],
#       dtype=object)

# %%
oct20states = october_data2020.State.unique()
oct20states.shape
oct20states
# Out:
# array(['California', 'Maryland', 'Texas', 'Pennsylvania',
#        'North Carolina', 'Connecticut', 'New Jersey', 'Florida',
#        'Washington', 'Michigan', 'New York', 'Illinois', 'Georgia',
#        'Indiana', 'Ohio', 'Missouri', 'Massachusetts', 'Kentucky',
#        'Louisiana', 'Utah', 'Arizona', 'Tennessee', 'Rhode Island',
#        'Arkansas', 'Oklahoma', 'Oregon', 'Wisconsin', 'Colorado',
#        'Mississippi', 'Virginia', 'Minnesota', 'Nevada', 'South Carolina',
#        'Nebraska'], dtype=object)

# %%
states = np.intersect1d(oct20states, oct19states, assume_unique=True)
states
# Out:
# array(['Arizona', 'California', 'Colorado', 'Connecticut', 'Florida',
#        'Georgia', 'Illinois', 'Indiana', 'Maryland', 'Michigan',
#        'Missouri', 'Nevada', 'New Jersey', 'New York', 'North Carolina',
#        'Ohio', 'Oklahoma', 'Pennsylvania', 'Tennessee', 'Texas', 'Utah',
#        'Virginia', 'Washington', 'Wisconsin'], dtype=object)

# %%
october_data2019.groupby('State').sum().reset_index().sort_values(by = 'Profit',ascending = False)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\41413340.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   october_data2019.groupby('State').sum().reset_index().sort_values(by = 'Profit',ascending = False)
#              State  Row ID+O6G3A1:R6      Sales  Quantity     Profit  Returns
# 1       California            278641  18173.008       247  2418.0945      0.0
# 12          Nevada             23454   4685.076        12  1691.3097      0.0
# 14        New York            195518   5878.826       125  1492.2662      0.0
# 11        Missouri             26804   2496.820        14  1028.7442      0.0
# 17        Oklahoma             58416   2358.470        38   557.3843      0.0
# 24       Wisconsin              9514   1649.750         5   544.4175      0.0
# 8          Indiana              3940   1424.900         5   356.2250      0.0
# 23      Washington             94678   1063.622        56   348.7464      0.0
# 3      Connecticut              1474   1179.270        17   311.3476      0.0
# 22        Virginia             27666    734.760        26   268.5228      0.0
# 13      New Jersey             22981   1753.040        29   262.3366      0.0
# 5          Florida             44083   1762.607        46   135.0560      0.0
# 10        Michigan             26004    448.620        27   134.2028      0.0
# 21            Utah              8710    219.120        24    95.8439      0.0
# 15  North Carolina             38630    347.567        21    57.9846      0.0
# 19       Tennessee             16315    419.208        15    33.4227      0.0
# 7         Illinois             20474     91.612        16    11.3074      0.0
# 6          Georgia              2341     41.860         7    10.4650      0.0
# 9         Maryland              4186     98.160         6     9.8160      0.0
# 4         Delaware              3486      7.920         4     3.5640      0.0
# 0          Arizona             17657    474.240        14   -62.5151      0.0
# 20           Texas             77262   2440.430        69  -108.1894      0.0
# 16            Ohio             60950   1896.774        71  -260.6210      0.0
# 18    Pennsylvania             26581   1642.422        19  -441.8017      0.0
# 2         Colorado             27636    980.068        13  -641.4625      0.0

# %%
october_data2020.groupby('State').sum().reset_index().sort_values(by = 'Profit',ascending = False)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\185137770.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   october_data2020.groupby('State').sum().reset_index().sort_values(by = 'Profit',ascending = False)
#              State  Row ID+O6G3A1:R6       Sales  Quantity     Profit  Returns
# 20        New York             60334   7723.4140        87  5593.9768      0.0
# 2       California            195596  15774.4710       173  3008.7412     16.0
# 8          Indiana             15201   2929.1900        30   531.0556      0.0
# 23        Oklahoma             17136   2555.5400        18   527.4027      0.0
# 10       Louisiana             27666   1811.5100        11   363.6841      0.0
# 15     Mississippi             20193    761.4600        18   286.0257      0.0
# 5          Florida             90443   4811.0580        59   265.0226      0.0
# 4      Connecticut             21693   1605.8400        21   248.4096      0.0
# 32      Washington             57547   3695.1960        47   243.6107      0.0
# 9         Kentucky             24839   1087.2900        31   200.2740      0.0
# 31        Virginia             13329    664.4300        12   173.8755      0.0
# 16        Missouri             15700   1332.9200        30   125.3079      0.0
# 18          Nevada              1517    904.6000         4   116.8720      0.0
# 1         Arkansas              8397    412.1700        11    92.9308      0.0
# 13        Michigan               644    149.5200         4    54.3332      0.0
# 12   Massachusetts             14683    536.0700        12    37.2347      0.0
# 33       Wisconsin             14701    299.7200        11    29.9220      0.0
# 11        Maryland              3256   2108.7800        11    29.7822      0.0
# 6          Georgia             16859    318.5300         7    20.1716      1.0
# 17        Nebraska              1509    301.5000         3    15.5250      1.0
# 14       Minnesota               175    182.1500         3     9.7534      0.0
# 19      New Jersey              1719    202.7700         3     7.1567      0.0
# 27  South Carolina              6909    372.7600         2     4.2804      0.0
# 30            Utah              7708    123.6800         2     4.2048      0.0
# 22            Ohio             36348   2051.6280        20   -15.5376      0.0
# 3         Colorado              9285    713.3040         8   -31.4912      0.0
# 26    Rhode Island             51484   1777.9000        26   -38.4080      0.0
# 24          Oregon             10007    951.2890        10   -64.1056      0.0
# 25    Pennsylvania            136522   6416.4610       118  -127.4638      0.0
# 0          Arizona             32485   2883.1580        42  -615.3185      0.0
# 29           Texas            124723   5913.3842        75  -825.1590      0.0
# 28       Tennessee             17987   2048.7860         9  -964.4829      0.0
# 21  North Carolina             53830   2671.4880        22 -1304.7078      0.0
# 7         Illinois             70239   3214.1950        51 -1430.8113      0.0

# %%
october_data2019.groupby('Segment').sum().reset_index().sort_values(by = 'Profit',ascending = False)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\1859534339.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   october_data2019.groupby('Segment').sum().reset_index().sort_values(by = 'Profit',ascending = False)
#        Segment  Row ID+O6G3A1:R6      Sales  Quantity     Profit  Returns
# 2  Home Office            237157  19322.016       221  4231.4582      0.0
# 0     Consumer            556369  18928.330       445  3161.2804      0.0
# 1    Corporate            323875  14017.804       260   863.7289      0.0

# %%
october_data2020.groupby('Segment').sum().reset_index().sort_values(by = 'Profit',ascending = False)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\2320288087.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   october_data2020.groupby('Segment').sum().reset_index().sort_values(by = 'Profit',ascending = False)
#        Segment  Row ID+O6G3A1:R6       Sales  Quantity     Profit  Returns
# 2  Home Office            181208  16194.7290       184  2684.5728      4.0
# 0     Consumer            537889  32503.4372       410  2163.5433      8.0
# 1    Corporate            461567  30607.9960       397  1723.9514      6.0

# %%
october_data2020.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit',ascending = False)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\4094985834.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   october_data2020.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit',ascending = False)
#    Sub-Category  Row ID+O6G3A1:R6       Sales  Quantity     Profit  Returns
# 6       Copiers              2624   2212.9680         4  3919.9888      0.0
# 13       Phones            130913  11227.8140       110  1680.6493      2.0
# 1    Appliances             56696   4873.3580        49  1012.8190      1.0
# 12        Paper            146989   6944.0640       122   632.9708      2.0
# 0   Accessories             90848   3986.8980        74   490.6074      0.0
# 14      Storage             90328   7151.5940        89   388.9901      0.0
# 7     Envelopes             41897   1592.7920        34   230.2544      1.0
# 10       Labels             69324   1843.0100        65   199.7789      4.0
# 2           Art             87597   2657.3200        74    97.4936      1.0
# 15     Supplies              3548    133.0600         2    10.5180      0.0
# 8     Fasteners             17782    360.9700         9     9.5425      0.0
# 9   Furnishings            105813   5223.7440        91    -1.4420      1.0
# 4     Bookcases             13503   1929.1922        17   -60.6598      1.0
# 5        Chairs             37584   4720.6100        33  -162.2495      1.0
# 3       Binders            182372  14060.9640       156  -290.0842      2.0
# 11     Machines              8647    778.9790         7  -543.9840      0.0
# 16       Tables             94199   9608.8250        55 -1043.1258      2.0

# %% [markdown]
# # Visulizations

# %% [markdown]
# ### Effect of city in profit

# %%
data1 = october_data2019.groupby('City').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
data2 = october_data2020.groupby('City').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\1845002033.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1 = october_data2019.groupby('City').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\1845002033.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data2 = october_data2020.groupby('City').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Assuming you have the data1 and data2 DataFrames as defined in your example

# # Merging the data for both years
# merged_data = data1.merge(data2, on='City', suffixes=('_2019', '_2020'))

# # Reshaping the data for Seaborn
# # reshaped_data = merged_data.melt(id_vars='City', var_name='Year', value_name='Profit').head(10)
# reshaped_data = merged_data.melt(id_vars='City', value_vars=['Profit_2019', 'Profit_2020'], 
#                                  var_name='Year', value_name='Profit')

# # Creating a figure and axes using Seaborn
# plt.figure(figsize=(12, 6))

# # Creating a clustered bar plot
# sns.barplot(x='City', y='Profit', hue='Year', data=reshaped_data)

# # Adding labels, title, and legend
# plt.xlabel('City')
# plt.ylabel('Profit')
# plt.title('Profit Comparison by City (2019 vs 2020)')
# plt.xticks(rotation=45)
# plt.legend(title='Year')

# # Display the plot
# plt.tight_layout()
# plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,5))

sns.barplot(x = 'City', y = 'Profit' ,data = data1,ax=axes[1])

sns.barplot(x = 'City', y = 'Profit' ,data = data2,ax=axes[0])

axes[0].set_title('2019')

axes[1].set_title('2020')

plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ### State

# %%
data1 = october_data2019.groupby('State').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
data2 = october_data2020.groupby('State').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,5))

sns.barplot(x = 'State', y = 'Profit' ,data = data1,ax=axes[1])

sns.barplot(x = 'State', y = 'Profit' ,data = data2,ax=axes[0])

axes[0].set_title('2019')

axes[1].set_title('2020')

plt.xticks(rotation = 45)

plt.show()
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\3051670344.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1 = october_data2019.groupby('State').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\3051670344.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data2 = october_data2020.groupby('State').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)

# %% [markdown]
# ### Sub-Categories

# %%
data1 = october_data2019.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
data2 = october_data2020.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,5))

sns.barplot(x = 'Sub-Category', y = 'Profit' ,data = data1,ax=axes[1])

sns.barplot(x = 'Sub-Category', y = 'Profit' ,data = data2,ax=axes[0])

axes[0].set_title('2019')

axes[1].set_title('2020')

plt.xticks(rotation = 45)

plt.show()
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\3945618199.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1 = october_data2019.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\3945618199.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data2 = october_data2020.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)

# %%
data1 = october_data2019.groupby('Segment').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
data2 = october_data2020.groupby('Segment').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,5))

sns.barplot(x = 'Segment', y = 'Profit' ,data = data1,ax=axes[1])

sns.barplot(x = 'Segment', y = 'Profit' ,data = data2,ax=axes[0])

axes[0].set_title('2019')

axes[1].set_title('2020')

plt.xticks(rotation = 45)

plt.show()
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\3224190694.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1 = october_data2019.groupby('Segment').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\3224190694.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data2 = october_data2020.groupby('Segment').sum().reset_index().sort_values(by = 'Profit',ascending = False).head(10)

# %%
october_data2019['Sales'].sum()
# october_data2020
# Out:
# 52268.149999999994

# %%
october_data2019['Profit'].sum()
# Out:
# 8256.467499999999

# %%
october_data2020['Sales'].sum()
# Out:
# 79306.1622

# %%
october_data2020['Profit'].sum()
# Out:
# 6572.067499999999

# %%
Noctober_data2019 = y2019[y2019['Order Date'].dt.month != 10]
Noctober_data2019
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0                 4918  CA-2019-160304 2019-01-01 2019-07-01  Standard Class
# 1                 4919  CA-2019-160304 2019-02-01 2019-07-01  Standard Class
# 2                 4920  CA-2019-160304 2019-02-01 2019-07-01  Standard Class
# 3                 3074  CA-2019-125206 2019-03-01 2019-05-01     First Class
# 4                 8604  US-2019-116365 2019-03-01 2019-08-01  Standard Class
# ...                ...             ...        ...        ...             ...
# 2583              6342  US-2019-105830 2019-12-31 2020-02-01     First Class
# 2584              4613  US-2019-165953 2019-12-31 2020-06-01  Standard Class
# 2585              5739  CA-2019-156139 2019-12-31 2020-06-01  Standard Class
# 2586              4614  US-2019-165953 2019-12-31 2020-06-01  Standard Class
# 2587              1153  CA-2019-160395 2019-12-31 2020-06-01  Standard Class
#
#      Customer ID      Customer Name    Segment        Country           City  \
# 0       BM-11575      Brendan Murry  Corporate  United States   Gaithersburg
# 1       BM-11575      Brendan Murry  Corporate  United States   Gaithersburg
# 2       BM-11575      Brendan Murry  Corporate  United States   Gaithersburg
# 3       LR-16915       Lena Radford   Consumer  United States    Los Angeles
# 4       CA-12310  Christine Abelman  Corporate  United States    San Antonio
# ...          ...                ...        ...            ...            ...
# 2583    DB-13660       Duane Benoit   Consumer  United States      Lancaster
# 2584    EP-13915         Emily Phan   Consumer  United States   Jacksonville
# 2585    BP-11155          Becky Pak   Consumer  United States  San Francisco
# 2586    EP-13915         Emily Phan   Consumer  United States   Jacksonville
# 2587    KL-16555      Kelly Lampkin  Corporate  United States           Reno
#
#            State   Region       Product ID         Category Sub-Category  \
# 0       Maryland     East  FUR-BO-10004709        Furniture    Bookcases
# 1       Maryland     East  FUR-BO-10004709        Furniture    Bookcases
# 2       Maryland     East  TEC-PH-10000455       Technology       Phones
# 3     California     West  OFF-ST-10003692  Office Supplies      Storage
# 4          Texas  Central  TEC-AC-10002217       Technology  Accessories
# ...          ...      ...              ...              ...          ...
# 2583        Ohio     East  OFF-ST-10002554  Office Supplies      Storage
# 2584     Florida    South  OFF-AR-10000588  Office Supplies          Art
# 2585  California     West  OFF-BI-10004233  Office Supplies      Binders
# 2586     Florida    South  OFF-PA-10002250  Office Supplies        Paper
# 2587      Nevada     West  OFF-AR-10003759  Office Supplies          Art
#
#                                            Product Name    Sales  Quantity  \
# 0     Bush Westfield Collection Bookcases, Medium Ch...   73.940         1
# 1     Bush Westfield Collection Bookcases, Medium Ch...  173.940         3
# 2                                           GE 30522EE2  231.980         2
# 3     Recycled Steel Personal File for Hanging File ...  114.460         2
# 4                   Imation Clip USB flash drive - 8 GB   30.080         2
# ...                                                 ...      ...       ...
# 2583                        Tennsco Industrial Shelving  156.512         4
# 2584                                         Newell 345   47.616         3
# 2585  GBC Pre-Punched Binding Paper, Plastic, White,...   38.376         3
# 2586                             Things To Do Today Pad   23.480         5
# 2587                   Crayola Anti Dust Chalk, 12/Pack    3.640         2
#
#        Profit  Returns Payment Mode
# 0     28.2668      NaN       Online
# 1     38.2668      NaN       Online
# 2     67.2742      NaN        Cards
# 3     28.6150      NaN       Online
# 4     -5.2640      NaN       Online
# ...       ...      ...          ...
# 2583 -35.2152      NaN       Online
# 2584   3.5712      NaN       Online
# 2585  13.4316      NaN          COD
# 2586   8.2180      NaN       Online
# 2587   1.6380      NaN          COD
#
# [2352 rows x 21 columns]

# %%
Noctober_data2019.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit', ascending = False)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\1877146908.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Noctober_data2019.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit', ascending = False)
#    Sub-Category  Row ID+O6G3A1:R6       Sales  Quantity      Profit  Returns
# 6       Copiers             91751  24699.4100        69  17742.7926      0.0
# 0   Accessories            837033  37899.7780       621   8714.3813      0.0
# 13       Phones           1009701  65231.0860       741   8183.4615      0.0
# 12        Paper           1576942  19625.1080      1213   8161.1179      0.0
# 3       Binders           1826784  35332.0930      1456   7830.3368      0.0
# 14      Storage            868788  51012.9980       706   5482.4150      0.0
# 5        Chairs            756410  75970.5740       564   5093.4953      0.0
# 1    Appliances            536007  21476.2850       359   4120.7235      0.0
# 9   Furnishings           1234580  25267.4540       926   3456.3533      0.0
# 11     Machines            157885  48207.2950       123   2848.7796      0.0
# 7     Envelopes            277251   4259.3500       206   1855.7649      0.0
# 2           Art            857505   5314.3460       620   1270.8916      0.0
# 10       Labels            454167   2691.8080       329   1132.1283      0.0
# 8     Fasteners            220930    869.5260       268    262.2273      0.0
# 4     Bookcases            252902  23754.2145       185     94.1632      0.0
# 15     Supplies            263837  14134.2800       197   -717.4515      0.0
# 16       Tables            443848  56665.7825       329  -1964.6070      0.0

# %%
october_data2019.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit', ascending = False)
# Out:
# C:\Users\Parn\AppData\Local\Temp\ipykernel_11048\2014158184.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   october_data2019.groupby('Sub-Category').sum().reset_index().sort_values(by = 'Profit', ascending = False)
#    Sub-Category  Row ID+O6G3A1:R6      Sales  Quantity     Profit  Returns
# 3       Binders            199089   7351.232       147  2385.2973      0.0
# 12       Phones            101990  10730.944        77  1276.1314      0.0
# 1    Appliances             40838   3574.030        37  1180.6180      0.0
# 0   Accessories             82320   3996.076        61   949.9072      0.0
# 11        Paper            166239   2036.786       159   910.4166      0.0
# 13      Storage             99350   5775.702       102   721.8718      0.0
# 5        Chairs             75711   5948.071        50   669.6586      0.0
# 8   Furnishings            107790   2606.670       110   478.9167      0.0
# 6     Envelopes             17134    470.540        16   210.9834      0.0
# 4     Bookcases             36589   1895.192        13   146.5746      0.0
# 2           Art             76034    646.562        58   143.0710      0.0
# 9        Labels             28872    135.432        34    60.4836      0.0
# 10     Machines             15339   3699.591         6    58.5384      0.0
# 7     Fasteners             30716     90.608        20    31.8461      0.0
# 14     Supplies             20871    143.296        19    18.4876      0.0
# 15       Tables             18519   3167.418        17  -986.3348      0.0
